# %%
# 인증키: 
# 팔당댐 관측소코드: 1017310
# http://www.hrfco.go.kr/web/openapiPage/reference.do#

# 0719 ~ 0731 팔당댐
# http://api.hrfco.go.kr/1567F679-A183-4E99-A02D-B1CA09D70E19/dam/list/10M/1017310/202207190000/202207312350.json

# %%
import datetime
import requests
import pandas as pd

# def 팔당댐_데이터_sub_request():
URL = f'http://api.hrfco.go.kr/1567F679-A183-4E99-A02D-B1CA09D70E19/dam/list/10M/1017310/202207190000/202207312350.json'
print(URL)
request_headers = { 
'User-Agent' : ('Mozilla/5.0 (Windows NT 10.0;Win64; x64)\
AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98\
Safari/537.36'), } 
response = requests.get(URL, headers = request_headers)
# return response.json()

# result = 팔당댐_데이터_sub_request()
result = response.json()
result['content'][0].keys()
tocsv = ''
for i in result['content'][-1::-1]:
    print(i['ymdhm'], i['swl'], i['inf'], i['sfw'], i['ecpc'], i['tototf'])
    tocsv += f"{i['ymdhm']}, {i['swl']}, {i['inf']}, {i['sfw']}, {i['ecpc']}, {i['tototf']}\n"
# Out:
# http://api.hrfco.go.kr/1567F679-A183-4E99-A02D-B1CA09D70E19/dam/list/10M/1017310/202207190000/202207312350.json
# 202207190000 25.040 255.360 212.860 31.140 255.360
# 202207190010 25.040 255.740 212.860 31.140 255.740
# 202207190020 25.040 257.420 212.860 31.140 257.420
# 202207190030 25.040 259.920 212.860 31.140 259.920
# 202207190040 25.050 866.020 213.230 30.770 259.350
# 202207190050 25.050 260.170 213.230 30.770 260.170
# 202207190100 25.050 259.450 213.230 30.770 259.450
# 202207190110 25.050 259.320 213.230 30.770 259.320
# 202207190120 25.060 868.290 213.590 30.410 259.960
# 202207190130 25.060 259.840 213.590 30.410 259.840
# 202207190140 25.060 259.740 213.590 30.410 259.740
# 202207190150 25.060 258.960 213.590 30.410 258.960
# 202207190200 25.060 259.470 213.590 30.410 259.470
# 202207190210 25.060 259.870 213.590 30.410 259.870
# 202207190220 25.070 867.940 213.960 30.040 259.600
# 202207190230 25.070 259.070 213.960 30.040 259.070
# ...

# %%
import datetime
import requests
import pandas as pd

# def 팔당댐_데이터_sub_request():
URL = f'http://api.hrfco.go.kr/1567F679-A183-4E99-A02D-B1CA09D70E19/dam/list/10M/1017310/202208010000/202208300840.json'
print(URL)
request_headers = { 
'User-Agent' : ('Mozilla/5.0 (Windows NT 10.0;Win64; x64)\
AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98\
Safari/537.36'), } 
response = requests.get(URL, headers = request_headers)
# return response.json()

# result = 팔당댐_데이터_sub_request()
result = response.json()
result['content'][0].keys()
for i in result['content'][-1::-1]:
    print(i['ymdhm'], i['swl'], i['inf'], i['sfw'], i['ecpc'], i['tototf'])
    tocsv += f"{i['ymdhm']}, {i['swl']}, {i['inf']}, {i['sfw']}, {i['ecpc']}, {i['tototf']}\n"
# Out:
# http://api.hrfco.go.kr/1567F679-A183-4E99-A02D-B1CA09D70E19/dam/list/10M/1017310/202208010000/202208300840.json
# 202208010000 24.870 538.340 206.730 37.270 538.340
# 202208010010 24.850 0.000 206.010 37.990 650.340
# 202208010020 24.850 664.420 206.010 37.990 664.420
# 202208010030 24.850 668.390 206.010 37.990 668.390
# 202208010040 24.850 669.460 206.010 37.990 669.460
# 202208010050 24.850 670.040 206.010 37.990 670.040
# 202208010100 24.840 77.090 205.650 38.350 672.090
# 202208010110 24.840 671.510 205.650 38.350 671.510
# 202208010120 24.840 671.390 205.650 38.350 671.390
# 202208010130 24.850 1262.480 206.010 37.990 667.480
# 202208010140 24.850 667.310 206.010 37.990 667.310
# 202208010150 24.850 667.240 206.010 37.990 667.240
# 202208010200 24.850 668.050 206.010 37.990 668.050
# 202208010210 24.840 73.690 205.650 38.350 668.690
# 202208010220 24.840 668.020 205.650 38.350 668.020
# 202208010230 24.840 667.840 205.650 38.350 667.840
# ...

# %%
with open("팔당댐.csv", 'w') as f:
    f.write(tocsv)
